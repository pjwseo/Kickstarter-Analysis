# %% [markdown]
# # Project: Kickstarter Project

# %% [markdown]
# ## Exploring Kickstarter Data and Identifying Key Factors for Project Success

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from patsy import dmatrices
import statsmodels.api as sm;
from datetime import *
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %matplotlib inline

# %%
# read in csv
df_og = pd.read_csv('ks-projects-201801.csv')

# %% [markdown]
# ## Introduction:

# %% [markdown]
# ## Data Assessment:

# %%
# visual assessment
df_og.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %% [markdown]
# * Does not look like we'll be needing the ID column for analysis
# * As usd conversion is already done for us, we won't be needing currency either (we still have country recorded)
# * Extract live_time from deadline - launched
# * Remove goal as well since we have usd_goal_real
# * Discrepancy between usd pledged and usd_pledged_real (Row #2) - We will take usd_pledged_real (converted by fixer.io api) over KS conversions due to errors

# %%
df_og.category.value_counts()
# Out:
# Product Design       22314
# Documentary          16139
# Music                15727
# Tabletop Games       14180
# Shorts               12357
# Video Games          11830
# Food                 11493
# Film & Video         10108
# Fiction               9169
# Fashion               8554
# Nonfiction            8318
# Art                   8253
# Apparel               7166
# Theater               7057
# Technology            6930
# Rock                  6758
# Children's Books      6756
# Apps                  6345
# Publishing            6018
# Webseries             5762
# Photography           5752
# Indie Rock            5657
# Narrative Film        5188
# Web                   5153
# Comics                4996
# Crafts                4664
# Country & Folk        4451
# Design                4199
# Hip-Hop               3912
# Hardware              3663
#                      ...
# Couture                275
# Blues                  268
# Animals                255
# Fabrication Tools      250
# Makerspaces            238
# Printing               238
# Movie Theaters         232
# Puzzles                231
# Bacon                  221
# Stationery             219
# Photo                  196
# Video Art              194
# Romance                190
# Knitting               181
# Workshops              164
# Crochet                162
# Translations           153
# Pet Fashion            139
# Glass                  138
# Latin                  137
# Embroidery             113
# Typography             108
# Pottery                100
# Weaving                 93
# Quilts                  81
# Residencies             69
# Letterpress             49
# Chiptune                35
# Literary Spaces         27
# Taxidermy               13
# Name: category, Length: 159, dtype: int64

# %%
df_og.main_category.value_counts()
# Out:
# Film & Video    63585
# Music           51918
# Publishing      39874
# Games           35231
# Technology      32569
# Design          30070
# Art             28153
# Food            24602
# Fashion         22816
# Theater         10913
# Comics          10819
# Photography     10779
# Crafts           8809
# Journalism       4755
# Dance            3768
# Name: main_category, dtype: int64

# %% [markdown]
# * Naming convention for main cateogy and category is confusing. Rename category as sub_category

# %%
df_og.state.value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
df_og.currency.value_counts()
# Out:
# USD    295365
# GBP     34132
# EUR     17405
# CAD     14962
# AUD      7950
# SEK      1788
# MXN      1752
# NZD      1475
# DKK      1129
# CHF       768
# NOK       722
# HKD       618
# SGD       555
# JPY        40
# Name: currency, dtype: int64

# %%
df_og.country.value_counts()
# Out:
# US      292627
# GB       33672
# CA       14756
# AU        7839
# DE        4171
# N,0"      3797
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         761
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# LU          62
# JP          40
# Name: country, dtype: int64

# %%
string = 'N,0"'
df_no = df_og.query('country == @string')

# %%
df_no.tail()
# Out:
#                ID                                               name  \
# 378233  997971307  EQUUS International Film Festival®, all-equine...
# 378303  998319149                            Emily 2050 - Short Film
# 378434    9988744                             Matthew Stephens Music
# 378585  999610349     Lady Vendredi: Afrofuturist concept 12 inch EP
# 378588  999621278                     Jeune auteur a besoin de vous!
#
#             category main_category currency    deadline    goal  \
# 378233  Film & Video  Film & Video      USD  2015-02-03  7500.0
# 378303  Film & Video  Film & Video      CAD  2014-05-23  3000.0
# 378434         Music         Music      USD  2016-02-05  5000.0
# 378585         Music         Music      GBP  2015-10-19  2000.0
# 378588    Publishing    Publishing      EUR  2015-11-20  1600.0
#
#                    launched  pledged      state  backers country  usd pledged  \
# 378233  2014-12-05 04:19:14     10.0  undefined        0    N,0"          NaN
# 378303  2014-04-08 00:30:09   3102.0  undefined        0    N,0"          NaN
# 378434  2016-01-06 21:59:23    235.0  undefined        0    N,0"          NaN
# 378585  2015-09-21 22:33:18   2125.0  undefined        0    N,0"          NaN
# 378588  2015-10-21 21:28:13      0.0  undefined        0    N,0"          NaN
#
#         usd_pledged_real  usd_goal_real
# 378233             10.00        7500.00
# 378303           2845.61        2752.04
# 378434            235.00        5000.00
# 378585           3273.36        3080.81
# 378588              0.00        1710.08

# %% [markdown]
# * Fix Typo in Country: N,0"
#   * Upon taking a closer look at rows with country listed as "N,0"" and each of the projects on kickstarter.com, there was no single country that all of these projects belonged to. I assume that it is being recorded as NA. Not all hope is lost though, I found that the currency is the perfect indicator as to which country the project belongs to. Therefore, we will need to keep the currency column to fill in N,0"s and drop it later on

# %%
df_og.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
# ID                  378661 non-null int64
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# currency            378661 non-null object
# deadline            378661 non-null object
# goal                378661 non-null float64
# launched            378661 non-null object
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 43.3+ MB

# %%
type(df_og.deadline[0])
# Out:
# str

# %%
type(df_og.launched[0])
# Out:
# str

# %% [markdown]
# * change both deadline and launch date to datetime object

# %% [markdown]
# ## Wrangling

# %%
df = df_og.copy()

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
# selecting columns I want to use for analysis
df = df[['name', 'main_category', 'category', 'currency', 'country', 'launched', 'deadline', 'state', 'backers', 'usd_pledged_real', 'usd_goal_real']]

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0                    The Songs of Adelaide & Abullah    Publishing
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Film & Video
# 2                                     Where is Hank?  Film & Video
# 3  ToshiCapital Rekordz Needs Help to Complete Album         Music
# 4  Community Film Project: The Art of Neighborhoo...  Film & Video
#
#          category currency country             launched    deadline     state  \
# 0          Poetry      GBP      GB  2015-08-11 12:12:28  2015-10-09    failed
# 1  Narrative Film      USD      US  2017-09-02 04:43:57  2017-11-01    failed
# 2  Narrative Film      USD      US  2013-01-12 00:20:50  2013-02-26    failed
# 3           Music      USD      US  2012-03-17 03:24:11  2012-04-16    failed
# 4    Film & Video      USD      US  2015-07-04 08:35:03  2015-08-29  canceled
#
#    backers  usd_pledged_real  usd_goal_real
# 0        0               0.0        1533.95
# 1       15            2421.0       30000.00
# 2        3             220.0       45000.00
# 3        1               1.0        5000.00
# 4       14            1283.0       19500.00

# %%
# renaming columns
df.columns = ['name', 'main_cat', 'sub_cat', 'currency', 'country', 'launch_date', 'deadline', 'state', 'backers', 'usd_pledged', 'usd_goal']

# %%
df.head()
# Out:
#                                                 name      main_cat  \
# 0                    The Songs of Adelaide & Abullah    Publishing
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Film & Video
# 2                                     Where is Hank?  Film & Video
# 3  ToshiCapital Rekordz Needs Help to Complete Album         Music
# 4  Community Film Project: The Art of Neighborhoo...  Film & Video
#
#           sub_cat currency country          launch_date    deadline     state  \
# 0          Poetry      GBP      GB  2015-08-11 12:12:28  2015-10-09    failed
# 1  Narrative Film      USD      US  2017-09-02 04:43:57  2017-11-01    failed
# 2  Narrative Film      USD      US  2013-01-12 00:20:50  2013-02-26    failed
# 3           Music      USD      US  2012-03-17 03:24:11  2012-04-16    failed
# 4    Film & Video      USD      US  2015-07-04 08:35:03  2015-08-29  canceled
#
#    backers  usd_pledged  usd_goal
# 0        0          0.0   1533.95
# 1       15       2421.0  30000.00
# 2        3        220.0  45000.00
# 3        1          1.0   5000.00
# 4       14       1283.0  19500.00

# %%
# Converting launch date and deadline to datetime object
df.launch_date = pd.to_datetime(df.launch_date)
df.deadline = pd.to_datetime(df.deadline)

# Creating project live time column by calculating difference between launch and deadline
df['live_days'] = (df.deadline - df.launch_date).apply(lambda x: x/np.timedelta64(1,'D'))

# %%
df.head()
# Out:
#                                                 name      main_cat  \
# 0                    The Songs of Adelaide & Abullah    Publishing
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Film & Video
# 2                                     Where is Hank?  Film & Video
# 3  ToshiCapital Rekordz Needs Help to Complete Album         Music
# 4  Community Film Project: The Art of Neighborhoo...  Film & Video
#
#           sub_cat currency country         launch_date   deadline     state  \
# 0          Poetry      GBP      GB 2015-08-11 12:12:28 2015-10-09    failed
# 1  Narrative Film      USD      US 2017-09-02 04:43:57 2017-11-01    failed
# 2  Narrative Film      USD      US 2013-01-12 00:20:50 2013-02-26    failed
# 3           Music      USD      US 2012-03-17 03:24:11 2012-04-16    failed
# 4    Film & Video      USD      US 2015-07-04 08:35:03 2015-08-29  canceled
#
#    backers  usd_pledged  usd_goal  live_days
# 0        0          0.0   1533.95  58.491343
# 1       15       2421.0  30000.00  59.802813
# 2        3        220.0  45000.00  44.985532
# 3        1          1.0   5000.00  29.858206
# 4       14       1283.0  19500.00  55.642326

# %%
# separate data into 2. One with countries listed as N,0" and the rest so we can fix and concatenate afterwards
df_no = df.query('country == @string')
df = df.query('country != @string')

# %%
# taking a look at currencies present 
df_no.currency.value_counts()
# Out:
# USD    2738
# GBP     460
# CAD     206
# EUR     186
# AUD     111
# SEK      31
# NZD      28
# DKK      16
# NOK      14
# CHF       7
# Name: currency, dtype: int64

# %%
# calculating proportion of countries with EURO as their main currency in df (not df_no)
n_eur = df.query('currency == "EUR"').country.count()
df.query('currency == "EUR"').country.value_counts() / n_eur
# Out:
# DE    0.242232
# FR    0.170684
# IT    0.167141
# NL    0.166560
# ES    0.132180
# IE    0.047099
# BE    0.035833
# AT    0.034671
# LU    0.003601
# Name: country, dtype: float64

# %%
print(n_eur)
# Out:
# 17219

# %% [markdown]
# n = 17,219

# %% [markdown]
# Approximate % of countries in each projects using EUR as main currency:
#
# * DE - 24
# * FR - 17
# * IT - 17
# * NL - 17
# * ES - 13
# * IE - 5
# * BE - 3
# * AT - 3
# * LU - 1

# %%
for i in df_no.index:
    # grab currency data
    ccy = df_no.get_value(i, 'currency')
    
    # USA
    if ccy == 'USD':
        df_no.set_value(i, 'country', 'US')
    
    # UK
    elif ccy == 'GBP':
        df_no.set_value(i, 'country', 'UK')
    
    # Canada    
    elif ccy == 'CAD':
        df_no.set_value(i, 'country', 'CA')
    
    # Euros - Since more than 1 country uses EUR, I will distribute each project into a random country following the proportion above
    elif ccy == 'EUR':
        x = np.random.randint(1, 100)
        
        if (x <= 24):
            df_no.set_value(i, 'country', 'DE')
        
        elif (x > 24) & (x <= 41):
            df_no.set_value(i, 'country', 'FR')
        
        elif (x > 41) & (x <= 58):
            df_no.set_value(i, 'country', 'IT')
            
        elif (x > 58) & (x <= 75):
            df_no.set_value(i, 'country', 'NL')
        
        elif (x > 75) & (x <= 88):
            df_no.set_value(i, 'country', 'ES')
        
        elif (x > 88) & (x <= 93):
            df_no.set_value(i, 'country', 'IE')
        
        elif (x > 93) & (x <= 96):
            df_no.set_value(i, 'country', 'BE')
            
        elif (x > 96) & (x <= 99):
            df_no.set_value(i, 'country', 'AT')
            
        elif (x == 100):
            df_no.set_value(i, 'country', 'LU')      
    
    # Australia
    elif ccy == 'AUD':
        df_no.set_value(i, 'country', 'AU')
    
    # Sweden
    elif ccy == 'SEK':
        df_no.set_value(i, 'country', 'SE')
       
    # New Zealand
    elif ccy == 'NZD':
        df_no.set_value(i, 'country', 'NZ')
    
    # Denmark
    elif ccy == 'DKK':
        df_no.set_value(i, 'country', 'DK')
     
    # Norway
    elif ccy == 'NOK':
        df_no.set_value(i, 'country', 'NO')
    
    # Switzerland
    elif ccy == 'CHF':
        df_no.set_value(i, 'country', 'CH')
# Out:
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:50: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:54: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:40: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:62: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:58: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:37: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:66: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:70: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# A:\Anaconda3\lib\site-packages\ipykernel\__main__.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
df_no.query('currency == "EUR"').country.value_counts()
# Out:
# DE    46
# FR    45
# NL    31
# IT    30
# ES    18
# IE     8
# BE     5
# AT     3
# Name: country, dtype: int64

# %% [markdown]
# Distribution here resembles the bigger sample from df (n = 17,219), which is a great sign!

# %%
# concatenate df_no back into df
df = pd.concat([df, df_no], ignore_index = True)

# %%
df.tail()
# Out:
#                                                      name      main_cat  \
# 378656  EQUUS International Film Festival®, all-equine...  Film & Video
# 378657                            Emily 2050 - Short Film  Film & Video
# 378658                             Matthew Stephens Music         Music
# 378659     Lady Vendredi: Afrofuturist concept 12 inch EP         Music
# 378660                     Jeune auteur a besoin de vous!    Publishing
#
#              sub_cat currency country         launch_date   deadline  \
# 378656  Film & Video      USD      US 2014-12-05 04:19:14 2015-02-03
# 378657  Film & Video      CAD      CA 2014-04-08 00:30:09 2014-05-23
# 378658         Music      USD      US 2016-01-06 21:59:23 2016-02-05
# 378659         Music      GBP      UK 2015-09-21 22:33:18 2015-10-19
# 378660    Publishing      EUR      BE 2015-10-21 21:28:13 2015-11-20
#
#             state  backers  usd_pledged  usd_goal  live_days
# 378656  undefined        0        10.00   7500.00  59.819977
# 378657  undefined        0      2845.61   2752.04  44.979062
# 378658  undefined        0       235.00   5000.00  29.083762
# 378659  undefined        0      3273.36   3080.81  27.060208
# 378660  undefined        0         0.00   1710.08  29.105405

# %% [markdown]
# I'm noticing some of the kickstarter projects that had backers (usd_pledged > 0) are showing up with 0 backers. I need to investigate this further:

# %%
df.query('backers == 0').usd_pledged.count()
# Out:
# 55609

# %%
df.query('backers == 0').usd_pledged.value_counts()
# Out:
# 0.00       52527
# 1.00         123
# 25.00         32
# 10.00         28
# 2.00          24
# 100.00        24
# 50.00         22
# 5.00          20
# 20.00         14
# 30.00         13
# 6.00          11
# 200.00        10
# 2000.00       10
# 51.00          9
# 3000.00        8
# 21.00          8
# 101.00         8
# 1500.00        8
# 120.00         7
# 5000.00        7
# 230.00         7
# 110.00         7
# 150.00         6
# 75.00          6
# 26.00          6
# 11.00          6
# 61.00          6
# 3.00           6
# 15.00          6
# 31.00          5
#            ...
# 4497.90        1
# 2975.00        1
# 423.00         1
# 2004.27        1
# 1.60           1
# 8830.00        1
# 4650.00        1
# 35.60          1
# 9855.00        1
# 218.00         1
# 440.00         1
# 704.00         1
# 69.86          1
# 265.66         1
# 1515.00        1
# 409.00         1
# 281.76         1
# 47.80          1
# 811.00         1
# 1774.43        1
# 537.42         1
# 2486.23        1
# 32.58          1
# 10.23          1
# 39.26          1
# 829.05         1
# 6376.00        1
# 32.06          1
# 5195.74        1
# 2595.00        1
# Name: usd_pledged, Length: 2294, dtype: int64

# %% [markdown]
# Out of 55,609 rows with 0 backers, 52,527 is correctly recorded as having received $0 in pledges. Since we cannot extract backer numbers from existing data, the only solution is manually fixing 3,000 projects, which is not practical at this point with our data already being a good size (~380k). I will remove these rows before moving on further:

# %%
# Drop rows specified above, and reset index
df.drop(df[(df.backers == 0) & (df.usd_pledged != 0)].index, inplace = True)
df.reset_index(drop = True, inplace = True)

# %%
df.tail()
# Out:
#                                                      name    main_cat  \
# 375574                                    Bydlo - A Novel  Publishing
# 375575  DEVELOP MAGAZINE FOR THE ARTS, MUSIC, AND DESI...  Publishing
# 375576                    "Songwriter assistance" service       Music
# 375577                  The World Needs More Big Thinkers  Publishing
# 375578                     Jeune auteur a besoin de vous!  Publishing
#
#            sub_cat currency country         launch_date   deadline      state  \
# 375574  Publishing      GBP      UK 2015-04-02 12:51:16 2015-06-01  undefined
# 375575  Publishing      USD      US 2015-01-29 17:43:13 2015-02-28  undefined
# 375576       Music      CAD      CA 2014-11-22 00:56:04 2014-12-22  undefined
# 375577  Publishing      USD      US 2015-07-30 03:01:31 2015-09-13  undefined
# 375578  Publishing      EUR      BE 2015-10-21 21:28:13 2015-11-20  undefined
#
#         backers  usd_pledged  usd_goal  live_days
# 375574        0          0.0   4599.39  59.464398
# 375575        0          0.0   5000.00  29.261655
# 375576        0          0.0   4313.32  29.961065
# 375577        0          0.0   8000.00  44.873947
# 375578        0          0.0   1710.08  29.105405

# %%
df.query('backers == 0').usd_pledged.value_counts()
# Out:
# 0.0    52527
# Name: usd_pledged, dtype: int64

# %% [markdown]
# All rows with 0 backers now have $0 in pledged amount.

# %%
len(df)
# Out:
# 375579

# %%
list(df.columns.values)
# Out:
# ['name',
#  'main_cat',
#  'sub_cat',
#  'currency',
#  'country',
#  'launch_date',
#  'deadline',
#  'state',
#  'backers',
#  'usd_pledged',
#  'usd_goal',
#  'live_days']

# %%
# re-ordering columns and now dropping currency
df = df[['name',
 'main_cat',
 'sub_cat',
 'country',
 'launch_date',
 'deadline',
 'live_days',
 'state',
 'backers',
 'usd_pledged',
 'usd_goal']]

# %%
# dropping NAs and duplicates
df.drop_duplicates(inplace = True)
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375575 entries, 0 to 375578
# Data columns (total 11 columns):
# name           375575 non-null object
# main_cat       375575 non-null object
# sub_cat        375575 non-null object
# country        375575 non-null object
# launch_date    375575 non-null datetime64[ns]
# deadline       375575 non-null datetime64[ns]
# live_days      375575 non-null float64
# state          375575 non-null object
# backers        375575 non-null int64
# usd_pledged    375575 non-null float64
# usd_goal       375575 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(5)
# memory usage: 34.4+ MB

# %%
df.head(10)
# Out:
#                                                 name      main_cat  \
# 0                    The Songs of Adelaide & Abullah    Publishing
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Film & Video
# 2                                     Where is Hank?  Film & Video
# 3  ToshiCapital Rekordz Needs Help to Complete Album         Music
# 4  Community Film Project: The Art of Neighborhoo...  Film & Video
# 5                               Monarch Espresso Bar          Food
# 6  Support Solar Roasted Coffee & Green Energy!  ...          Food
# 7  Chaser Strips. Our Strips make Shots their B*tch!          Food
# 8  SPIN - Premium Retractable In-Ear Headphones w...        Design
# 9  STUDIO IN THE SKY - A Documentary Feature Film...  Film & Video
#
#           sub_cat country         launch_date   deadline  live_days  \
# 0          Poetry      GB 2015-08-11 12:12:28 2015-10-09  58.491343
# 1  Narrative Film      US 2017-09-02 04:43:57 2017-11-01  59.802813
# 2  Narrative Film      US 2013-01-12 00:20:50 2013-02-26  44.985532
# 3           Music      US 2012-03-17 03:24:11 2012-04-16  29.858206
# 4    Film & Video      US 2015-07-04 08:35:03 2015-08-29  55.642326
# 5     Restaurants      US 2016-02-26 13:38:27 2016-04-01  34.431632
# 6            Food      US 2014-12-01 18:30:44 2014-12-21  19.228657
# 7          Drinks      US 2016-02-01 20:05:12 2016-03-17  44.163056
# 8  Product Design      US 2014-04-24 18:14:43 2014-05-29  34.239780
# 9     Documentary      US 2014-07-11 21:55:48 2014-08-10  29.086250
#
#         state  backers  usd_pledged   usd_goal
# 0      failed        0         0.00    1533.95
# 1      failed       15      2421.00   30000.00
# 2      failed        3       220.00   45000.00
# 3      failed        1         1.00    5000.00
# 4    canceled       14      1283.00   19500.00
# 5  successful      224     52375.00   50000.00
# 6  successful       16      1205.00    1000.00
# 7      failed       40       453.00   25000.00
# 8    canceled       58      8233.00  125000.00
# 9    canceled       43      6240.57   65000.00

# %% [markdown]
# ## Exploratory Visuals

# %% [markdown]
# ### Live Days

# %%
df.live_days.describe()
# Out:
# count    375575.000000
# mean         33.929439
# std          66.175520
# min           0.005058
# 25%          29.097946
# 50%          29.690289
# 75%          36.737378
# max       16738.958333
# Name: live_days, dtype: float64

# %%
df.sort_values(by = 'live_days', ascending = False)
# Out:
#                                                      name      main_cat  \
# 315802                       Student Auditions Music 2015    Publishing
# 2808       Salt of the Earth: A Dead Sea Movie (Canceled)  Film & Video
# 47691   1st Super-Size Painting - Social Network Owned...           Art
# 93647   Support Solo Theater! Help "Ungrateful Daughte...       Theater
# 74664                                 "ICHOR"  (Canceled)  Film & Video
# 245439  Help RIZ Make A Charity Album: 8 Songs, 8 Caus...         Music
# 271039     Identity Communications Infographic (Canceled)        Design
# 73477                     SmoothnFusion Jazz Comedy Album         Music
# 198315                                    We Were Vampire  Film & Video
# 302070                               once upon a mountain  Film & Video
# 204551                           Dark Timber Feature Film  Film & Video
# 133759           Send Up For Nothing across the country!!         Music
# 235984  'Do What You Love'   Live your Dreams - a P. J...  Film & Video
# 240951                          Angie McClure's new album         Music
# 97813                    "Distribution Point" Demo Shoot   Film & Video
# 272673                                The Secrets To Life         Music
# 148785  Misisipi Mike Wolf's 2nd Album - Enjoy Irrespo...         Music
# 224111            The new album by TA-80: Will Bury You!!         Music
# 67212   Men Who Dance With Men, Photographic Documentary    Photography
# 84867   CanStar LLC Kickstarts Fundraising for 'Vincen...       Theater
# 223942  Wales & The Welsh - the shaping of a people an...  Film & Video
# 172188           Uptown Praise Band 2nd Recording Project         Music
# 22379                  Fair Trade Fashion by SET Boutique       Fashion
# 152030                           Legend of the Peach Girl         Games
# 87221   Traditions Build Winners as the Snipe Class tu...  Film & Video
# 38105                               TRI TOUCH MUSIC KIOSK    Technology
# 150326         STAINED GLASS a feature film by Rich Owens  Film & Video
# 60432         A Somewhat Secret Place: Disability and Art           Art
# 169258                                           Cinema41  Film & Video
# 324534                              UN1TY Lacrosse Movie!  Film & Video
# ...                                                   ...           ...
# 153497                                     Virgo's Stitch       Fashion
# 278591                                   Music in Ireland         Music
# 34240                            Björk Swan Dress T-Shirt           Art
# 368629                        Cookie Fury : The 3.5$ Game         Games
# 359880                                    The Kale Effect    Publishing
# 182745                       INTO MYSTERY: Clue 01 ***box        Design
# 266018                  Another Fucking Warhol Production         Dance
# 244141                                 Fanfiction For You    Publishing
# 117240                     Clock in the shape of an Apple        Design
# 127551  A radio/TV station showcasing underground musi...         Music
# 331973                             The Drop: VIP Party II           Art
# 20759                                               iHelp    Technology
# 189009            Sexy Astronaut for It's a Spaceship Now       Theater
# 353465               Recording New Composition in Ireland         Music
# 889                                                Zombme         Games
# 128035                            Adventure Time Cupcakes          Food
# 361750  CXL - Feature Film - The 24 Hour Kickstarter. ...  Film & Video
# 319716                             [GLMG]Server Community         Games
# 154850    SEVEN HUNDRED AND SEVENTY-SEVEN DAYS: A JOURNEY    Publishing
# 309409                                 Sweet PB&J Fantasy          Food
# 37241                                          SOLE TOTES       Fashion
# 241792                              Hand Carved Necklaces           Art
# 195911                               Ceramic Cookware Set        Design
# 69353                               Dat Ass Up (Canceled)       Fashion
# 171025                                    Tally Streaming    Technology
# 367187                              Living Your Best Life           Art
# 65100                             Freshman Survival Guide    Publishing
# 180948                               PLANTATION POLITICS.         Music
# 178400         Successful E3 Conference for Dummies Short           Art
# 154869                            A Labradoodle Photobook   Photography
#
#                 sub_cat country         launch_date   deadline     live_days  \
# 315802       Publishing      CH 1970-01-01 01:00:00 2015-10-31  16738.958333
# 2808       Film & Video      US 1970-01-01 01:00:00 2010-09-15  14866.958333
# 47691               Art      US 1970-01-01 01:00:00 2010-08-14  14834.958333
# 93647           Theater      US 1970-01-01 01:00:00 2010-06-01  14760.958333
# 74664      Film & Video      US 1970-01-01 01:00:00 2010-05-21  14749.958333
# 245439            Music      US 1970-01-01 01:00:00 2010-05-04  14732.958333
# 271039           Design      US 1970-01-01 01:00:00 2010-04-10  14708.958333
# 73477              Jazz      US 2010-12-30 00:53:47 2011-04-01     91.962650
# 198315     Film & Video      US 2011-01-02 01:34:48 2011-04-04     91.934167
# 302070      Documentary      US 2011-01-02 02:35:59 2011-04-04     91.891678
# 204551           Shorts      US 2010-12-30 04:11:49 2011-04-01     91.825127
# 133759              Pop      US 2010-12-30 05:00:03 2011-04-01     91.791632
# 235984      Documentary      US 2011-01-02 07:16:22 2011-04-04     91.696968
# 240951       Indie Rock      US 2011-01-02 07:39:52 2011-04-04     91.680648
# 97813       Documentary      US 2011-01-01 10:00:56 2011-04-03     91.582685
# 272673             Rock      US 2010-12-30 10:01:11 2011-04-01     91.582512
# 148785   Country & Folk      US 2010-12-31 10:05:54 2011-04-02     91.579236
# 224111             Rock      US 2011-01-02 10:52:58 2011-04-04     91.546551
# 67212       Photography      US 2011-01-01 15:02:54 2011-04-03     91.372986
# 84867           Theater      US 2010-12-31 18:12:36 2011-04-02     91.241250
# 223942      Documentary      US 2010-12-31 19:01:33 2011-04-02     91.207257
# 172188          Hip-Hop      US 2010-12-31 19:38:44 2011-04-02     91.181435
# 22379           Fashion      US 2011-01-02 20:21:23 2011-04-04     91.151817
# 152030      Video Games      US 2011-03-20 23:12:26 2011-06-20     91.033032
# 87221       Documentary      US 2010-12-29 23:22:08 2011-03-31     91.026296
# 38105        Technology      US 2011-03-15 23:40:04 2011-06-15     91.013843
# 150326     Film & Video      US 2011-03-24 23:44:10 2011-06-24     91.010995
# 60432               Art      US 2011-03-21 23:49:31 2011-06-21     91.007280
# 169258     Film & Video      US 2011-03-22 23:58:12 2011-06-22     91.001250
# 324534           Shorts      US 2011-01-21 00:00:25 2011-04-22     90.999711
# ...                 ...     ...                 ...        ...           ...
# 153497          Apparel      US 2016-10-20 17:26:06 2016-10-21      0.273542
# 278591  Classical Music      US 2017-06-20 17:42:09 2017-06-21      0.262396
# 34240    Conceptual Art      US 2012-02-16 17:56:27 2012-02-17      0.252465
# 368629   Tabletop Games      FR 2017-08-05 18:05:40 2017-08-06      0.246065
# 359880       Publishing      US 2012-11-25 18:05:51 2012-11-26      0.245938
# 182745           Design      US 2012-12-12 18:12:25 2012-12-13      0.241377
# 266018     Performances      US 2017-05-10 18:15:14 2017-05-11      0.239421
# 244141          Fiction      US 2015-10-19 18:17:16 2015-10-20      0.238009
# 117240           Design      US 2015-04-30 18:20:44 2015-05-01      0.235602
# 127551          Hip-Hop      GB 2015-08-13 18:40:44 2015-08-14      0.221713
# 331973              Art      US 2009-10-02 18:47:10 2009-10-03      0.217245
# 20759              Apps      US 2017-05-21 18:55:04 2017-05-22      0.211759
# 189009          Theater      US 2015-09-26 18:55:10 2015-09-27      0.211690
# 353465  Classical Music      US 2017-06-21 18:59:18 2017-06-22      0.208819
# 889         Video Games      GB 2015-06-10 19:03:39 2015-06-11      0.205799
# 128035             Food      US 2014-07-28 19:28:36 2014-07-29      0.188472
# 361750   Narrative Film      US 2011-07-06 19:30:17 2011-07-07      0.187303
# 319716      Video Games      GB 2014-10-01 19:59:35 2014-10-02      0.166956
# 154850       Publishing      GB 2015-05-15 20:48:39 2015-05-16      0.132882
# 309409      Restaurants      US 2015-01-20 20:57:42 2015-01-21      0.126597
# 37241       Accessories      US 2016-07-23 21:07:12 2016-07-24      0.120000
# 241792              Art      US 2017-10-20 21:16:30 2017-10-21      0.113542
# 195911   Product Design      CA 2015-10-26 21:37:54 2015-10-27      0.098681
# 69353           Fashion      US 2013-05-09 21:42:15 2013-05-10      0.095660
# 171025              Web      US 2016-10-27 21:44:46 2016-10-28      0.093912
# 367187      Digital Art      SG 2016-08-01 21:44:53 2016-08-02      0.093831
# 65100        Publishing      US 2012-03-30 22:11:20 2012-03-31      0.075463
# 180948          Hip-Hop      US 2014-05-30 22:17:03 2014-05-31      0.071493
# 178400      Mixed Media      US 2015-06-17 23:08:53 2015-06-18      0.035498
# 154869       Photobooks      US 2016-11-10 23:52:43 2016-11-11      0.005058
#
#              state  backers  usd_pledged   usd_goal
# 315802   suspended        0         0.00    1905.97
# 2808      canceled        0         0.00    5000.00
# 47691     canceled        0         0.00   15000.00
# 93647     canceled        0         0.00    4000.00
# 74664     canceled        0         0.00     700.00
# 245439    canceled        0         0.00   10000.00
# 271039    canceled        0         0.00     500.00
# 73477       failed        3       146.00   12500.00
# 198315      failed        0         0.00  250000.00
# 302070      failed        4      1530.00   20000.00
# 204551      failed        4        60.00    5000.00
# 133759      failed       31      2055.00   10000.00
# 235984      failed        0         0.00   12977.00
# 240951  successful       63      5275.00    5000.00
# 97813       failed        1        50.00    5000.00
# 272673      failed       25       470.00    3000.00
# 148785  successful       31      1710.00    1500.00
# 224111      failed        1        20.80     500.00
# 67212       failed       66      3805.00   12000.00
# 84867   successful       93      7358.00    7000.00
# 223942      failed       15       550.00    5900.00
# 172188      failed        0         0.00    3800.00
# 22379       failed       20       817.00    7000.00
# 152030      failed       14       521.00    1000.00
# 87221   successful       56      7625.00    7500.00
# 38105       failed        1       100.00   65000.00
# 150326      failed        2      1025.00   50000.00
# 60432       failed       71      2931.00   10000.00
# 169258  successful       17       500.00     500.00
# 324534      failed       74      5630.00   70000.00
# ...            ...      ...          ...        ...
# 153497      failed        1         1.00    1000.00
# 278591      failed        1        22.00    1500.00
# 34240   successful       45       472.00     180.00
# 368629    canceled        2         7.06      81.18
# 359880      failed        0         0.00     500.00
# 182745  successful        9        42.00       4.00
# 266018  successful      161      7740.26    5000.00
# 244141  successful       47       320.00     100.00
# 117240      failed        0         0.00    1000.00
# 127551      failed        0         0.00   23452.16
# 331973  successful        5       640.00      10.00
# 20759     canceled        0         0.00    2750.00
# 189009  successful       13        61.00      24.00
# 353465      failed        0         0.00    1500.00
# 889         failed        1        30.97    7743.29
# 128035      failed        2        10.00     200.00
# 361750  successful       70      5018.05    5000.00
# 319716      failed        0         0.00    7551.17
# 154850      failed        1        15.64   31280.30
# 309409      failed        1         2.00      17.00
# 37241       failed        0         0.00   30000.00
# 241792  successful        1        12.00      10.00
# 195911      failed        0         0.00   11385.20
# 69353     canceled      131       625.45      50.00
# 171025      failed        0         0.00    7000.00
# 367187  successful        4         5.98       3.73
# 65100   successful        2        70.00      50.00
# 180948      failed        3        75.00    2500.00
# 178400      failed        0         0.00      50.00
# 154869  successful        8        18.00       5.00
#
# [375575 rows x 11 columns]

# %% [markdown]
# There is an erroneous data with project live days recorded as 14708 days and above, which is just not possible when we consider that kickstarter launched on April 28, 2009. We will filter all data with live_days greater than 14000 days

# %%
df.drop(df[df.live_days > 14000].index, inplace = True)

# %%
df.live_days.describe()
# Out:
# count    375568.000000
# mean         33.649447
# std          12.814460
# min           0.005058
# 25%          29.097940
# 50%          29.690266
# 75%          36.735188
# max          91.962650
# Name: live_days, dtype: float64

# %%
bin_edge = np.arange(0, 95, 5)
plt.hist(data = df, x = 'live_days', bins = bin_edge)
plt.xticks(bin_edge)
plt.xlabel('Live Days')
plt.ylabel('count')
plt.title('Distribution of Live Days');

# %%
df.query('live_days >= 25 and live_days <= 35').live_days.count() / len(df)
# Out:
# 0.5977852213181102

# %% [markdown]
# Majority (~59.8%) of all projects were run for anywhere from 25 to 35 days; Typically lasting for about a month

# %% [markdown]
# ### Main & Sub Category

# %%
base_color = sb.color_palette()[0]
cat_order = df.main_cat.value_counts().index
sb.countplot(data = df, x = 'main_cat', color = base_color, order = cat_order)
plt.xlabel('Main Category')
plt.ylabel('Count')
plt.title('Distribution of Main Category')
plt.xticks(rotation = 90);

# %% [markdown]
# Film & Video projects were the most created kickstarter projects, while Dance and Journalism were the least likely project to be created. Let's take a look at the sub-categories of Film & Video.

# %%
# 2019 03 13 - save csv for analysis
df.to_csv('temp.csv')
